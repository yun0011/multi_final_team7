# %% [markdown]
# 하천 계곡 위험지역

# %%
#중점 관리 지역
import requests
import pprint
import xml.etree.ElementTree as ET
import pandas as pd


url = "http://safemap.go.kr/openApiService/data/getWtrPlayData.do"
params = {
"serviceKey": "PHUYHKKL-PHUY-PHUY-PHUY-PHUYHKKLT1",
"numOfRows": "1334",
"pageNo": "1"
}

response = requests.get(url, params=params)

content = response.text

root = ET.fromstring(content)

# XML 데이터 구조 탐색
items = root.find("body").find("items")

counter = 0  # 반복 횟수를 저장할 변수

df1 = pd.DataFrame()  # 데이터를 저장할 데이터프레임 생성

for item in items.findall("item"):
    wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
    manage_at = item.find("MANAGE_AT").text

    if manage_at == "1" :
        counter += 1  # 반복 횟수 증가
        # 추출한 데이터 처리
        wtrplay_plc_nm = item.find("WTRPLAY_PLC_NM").text
        ctprvn_nm = item.find("CTPRVN_NM").text
        sgg_nm = item.find("SGG_NM").text
        emd_nm = item.find("EMD_NM").text
        detail_plcnm = item.find("DETAIL_PLCNM").text
        adres = item.find("ADRES").text
        wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
        wtrplay_sec = item.find("WTRPLAY_SEC").text
        wtrplay_deep = item.find("WTRPLAY_DEEP").text
        wtrplay_deep_avg = item.find("WTRPLAY_DEEP_AVG").text
        year_visitor = item.find("YEAR_VISITOR").text
        acdt_co = item.find("ACDT_CO").text
        x = item.find("X").text
        y = item.find("Y").text
        manage_type = item.find("MANAGEMENT_TYPE").text
        manage_at = item.find("MANAGE_AT").text

        #추출한 데이터 데이터프레임으로 변경
        df = pd.DataFrame( 
           [[wtrplay_plc_nm, ctprvn_nm, sgg_nm, emd_nm, detail_plcnm, adres, wtrplay_plc_type, wtrplay_sec, wtrplay_deep, wtrplay_deep_avg, year_visitor, acdt_co, x, y, manage_type, manage_at]],

            columns=["wtrplay_plc_nm", "ctprvn_nm", "sgg_nm", "emd_nm", "detail_plcnm", "adres", "wtrplay_plc_type", "wtrplay_sec", "wtrplay_deep", "wtrplay_deep_avg", "year_visitor", "acdt_co", "x", "y", "manage_type", "manage_at"]
        )

        # 데이터프레임에 추출한 데이터 추가
        df1 = pd.concat([df1, df])

print(df1)

print("반복 횟수:", counter)

df1.to_csv("중점관리지역_하천계곡곡.csv", index=False, encoding="cp949")
# Out:
#    wtrplay_plc_nm ctprvn_nm sgg_nm emd_nm detail_plcnm
# 0            장산계곡     부산광역시   해운대구     우동         장산계곡  \
# 0          용소천 계곡     부산광역시    기장군    장안읍          용소천
# 0         청소년수련원앞     대전광역시     중구    침산동     401번지 일원
# 0           침산교아래     대전광역시     중구    침산동     398번지 일원
# 0          상보안유원지     대전광역시     서구    흑석동        738번지
# ..            ...       ...    ...    ...          ...
# 0             운문암       강원도    양양군    현북면         null
# 0          부소치교 밑       강원도    양양군    현북면         null
# 0             내현보       강원도    양양군     서면         null
# 0           수리세월교       강원도    양양군     서면         null
# 0           수리1교밑       강원도    양양군     서면         null
#
#                        adres wtrplay_plc_type wtrplay_sec wtrplay_deep
# 0           부산광역시 해운대구 우동 산2               계곡        null          1.5  \
# 0   부산광역시 기장군 장안읍 반룡리 786-21               계곡          90            2
# 0           대전광역시 중구 침산동 401               하천         200            5
# 0           대전광역시 중구 침산동 398               하천         100            3
# 0           대전광역시 서구 흑석동 738               하천         600            2
# ..                       ...              ...         ...          ...
# 0     강원도 양양군 현북면 어성전리 815-5             산간계곡           2            1
# 0       강원도 양양군 현북면 장리 110-1               하천           1            1
# 0         강원도 양양군 서면 내현리 242               하천           2            1
# 0          강원도 양양군 서면 수리 688               하천           2            1
# 0        강원도 양양군 서면 수리 745-1               하천           2            1
#
#    wtrplay_deep_avg year_visitor acdt_co            x            y
# 0                 1          250       1  14378152.95  4189344.087  \
# 0                 2            1       0  14388739.58   4209991.05
# 0                 1            2       0   14180819.9  4337751.882
# 0                 1            1       0  14181658.49  4339178.339
# 0                 1            9       0  14175754.49  4338756.414
# ..              ...          ...     ...          ...          ...
# 0               0.5            0       0  14320821.77  4570740.083
# 0               0.3            0       0   14320208.6  4579400.879
# 0               0.2            0       0  14316612.58  4583469.592
# 0               0.2            0       0  14315390.95  4584968.671
# 0               0.3            0       0  14315890.62   4585952.43
#
#    manage_type manage_at
# 0       중점관리지역         1
# 0       중점관리지역         1
# 0       중점관리지역         1
# 0       중점관리지역         1
# 0       중점관리지역         1
# ..         ...       ...
# 0       중점관리지역         1
# 0       중점관리지역         1
# 0       중점관리지역         1
# 0       중점관리지역         1
# 0       중점관리지역         1
#
# [258 rows x 16 columns]
# 반복 횟수: 258

# %%
#일반지역
import requests
import pprint
import xml.etree.ElementTree as ET
import pandas as pd


url = "http://safemap.go.kr/openApiService/data/getWtrPlayData.do"
params = {
"serviceKey": "PHUYHKKL-PHUY-PHUY-PHUY-PHUYHKKLT1",
"numOfRows": "1334",
"pageNo": "1"
}

response = requests.get(url, params=params)

content = response.text

root = ET.fromstring(content)

# XML 데이터 구조 탐색
items = root.find("body").find("items")

counter = 0  # 반복 횟수를 저장할 변수

df1 = pd.DataFrame()  # 데이터를 저장할 데이터프레임 생성

for item in items.findall("item"):
    wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
    manage_at = item.find("MANAGE_AT").text

    if manage_at == "2" :
        counter += 1  # 반복 횟수 증가
        # 추출한 데이터 처리
        wtrplay_plc_nm = item.find("WTRPLAY_PLC_NM").text
        ctprvn_nm = item.find("CTPRVN_NM").text
        sgg_nm = item.find("SGG_NM").text
        emd_nm = item.find("EMD_NM").text
        detail_plcnm = item.find("DETAIL_PLCNM").text
        adres = item.find("ADRES").text
        wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
        wtrplay_sec = item.find("WTRPLAY_SEC").text
        wtrplay_deep = item.find("WTRPLAY_DEEP").text
        wtrplay_deep_avg = item.find("WTRPLAY_DEEP_AVG").text
        year_visitor = item.find("YEAR_VISITOR").text
        acdt_co = item.find("ACDT_CO").text
        x = item.find("X").text
        y = item.find("Y").text
        manage_type = item.find("MANAGEMENT_TYPE").text
        manage_at = item.find("MANAGE_AT").text

        #추출한 데이터 데이터프레임으로 변경
        df = pd.DataFrame( 
           [[wtrplay_plc_nm, ctprvn_nm, sgg_nm, emd_nm, detail_plcnm, adres, wtrplay_plc_type, wtrplay_sec, wtrplay_deep, wtrplay_deep_avg, year_visitor, acdt_co, x, y, manage_type, manage_at]],

            columns=["wtrplay_plc_nm", "ctprvn_nm", "sgg_nm", "emd_nm", "detail_plcnm", "adres", "wtrplay_plc_type", "wtrplay_sec", "wtrplay_deep", "wtrplay_deep_avg", "year_visitor", "acdt_co", "x", "y", "manage_type", "manage_at"]
        )

        # 데이터프레임에 추출한 데이터 추가
        df1 = pd.concat([df1, df])

print(df1)

print("반복 횟수:", counter)

df1.to_csv("일반지역_하천계곡.csv", index=False, encoding="cp949")
# Out:
#    wtrplay_plc_nm ctprvn_nm sgg_nm emd_nm        detail_plcnm
# 0    관악산계곡어린이물놀이장       서울시    관악구    신림로              신림계곡지구  \
# 0          장안사 계곡     부산광역시    기장군    장안읍                 장안사
# 0      임곡교 밑 징검다리     광주광역시    광산구     선동  임곡교 밑 상,하류 징검다리 사이
# 0          초지공원 앞     대전광역시     동구    대별동             산 5-8번지
# 0           복수교인근     대전광역시     중구    침산동          586-1번지 일원
# ..            ...       ...    ...    ...                 ...
# 0         원일전리 돔뜰       강원도    양양군    현북면                null
# 0       원일전리마을휴양지       강원도    양양군    현북면                null
# 0        내현보(모래소)       강원도    양양군     서면                null
# 0        수리보 밤나무집       강원도    양양군     서면                null
# 0      용천보(한남초교앞)       강원도    양양군     서면                null
#
#                        adres wtrplay_plc_type wtrplay_sec wtrplay_deep
# 0        서울시 관악구 신림동 808-125               계곡         150            1  \
# 0   부산광역시 기장군 장안읍 장안리 664-21               계곡         150          1.5
# 0         광주광역시 광산구 선동 311-1               하천         200            1
# 0         대전광역시 동구 대별동 산 5-8               하천         200            1
# 0         대전광역시 중구 침산동 586-1               하천      1500.0            2
# ..                       ...              ...         ...          ...
# 0     강원도 양양군 현북면 원일전리 566-3               하천           2            1
# 0     강원도 양양군 현북면 원일전리 273-3               하천           2            1
# 0        강원도 양양군 서면 내현리 17-4               하천           3            1
# 0          강원도 양양군 서면 수리 300               하천           2            1
# 0       강원도 양양군 서면 용천리 540-3               하천           2            1
#
#    wtrplay_deep_avg year_visitor acdt_co            x            y
# 0               0.6           11       0  14131845.97  4503708.725  \
# 0                 1          100       0  14385251.64  4214446.418
# 0               0.3          0.2       1   14109864.9  4192260.635
# 0               0.5            2       0  14189072.95  4338782.995
# 0                 1            1       0  14181237.94  4339434.665
# ..              ...          ...     ...          ...          ...
# 0                 2            0       0  14321543.93  4574564.858
# 0                 2            0       0  14322338.64  4576411.738
# 0               0.3            0       0  14317882.81  4582436.116
# 0               0.6            0       0  14315902.54  4583439.745
# 0               0.6            0       0  14316267.52   4587321.62
#
#    manage_type manage_at
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# ..         ...       ...
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
#
# [843 rows x 16 columns]
# 반복 횟수: 843

# %%
#일반지역
import requests
import pprint
import xml.etree.ElementTree as ET
import pandas as pd


url = "http://safemap.go.kr/openApiService/data/getWtrPlayData.do"
params = {
"serviceKey": "PHUYHKKL-PHUY-PHUY-PHUY-PHUYHKKLT1",
"numOfRows": "1334",
"pageNo": "1"
}

response = requests.get(url, params=params)

content = response.text

root = ET.fromstring(content)

# XML 데이터 구조 탐색
items = root.find("body").find("items")

counter = 0  # 반복 횟수를 저장할 변수

df1 = pd.DataFrame()  # 데이터를 저장할 데이터프레임 생성

for item in items.findall("item"):
    wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
    manage_at = item.find("MANAGE_AT").text

    if manage_at == "1" :
        counter += 1  # 반복 횟수 증가
        # 추출한 데이터 처리
        wtrplay_plc_nm = item.find("WTRPLAY_PLC_NM").text
        ctprvn_nm = item.find("CTPRVN_NM").text
        sgg_nm = item.find("SGG_NM").text
        emd_nm = item.find("EMD_NM").text
        detail_plcnm = item.find("DETAIL_PLCNM").text
        adres = item.find("ADRES").text
        wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
        wtrplay_sec = item.find("WTRPLAY_SEC").text
        wtrplay_deep = item.find("WTRPLAY_DEEP").text
        wtrplay_deep_avg = item.find("WTRPLAY_DEEP_AVG").text
        year_visitor = item.find("YEAR_VISITOR").text
        acdt_co = item.find("ACDT_CO").text
        x = item.find("X").text
        y = item.find("Y").text
        manage_type = item.find("MANAGEMENT_TYPE").text
        manage_at = item.find("MANAGE_AT").text

        #추출한 데이터 데이터프레임으로 변경
        df = pd.DataFrame( 
           [[wtrplay_plc_nm, ctprvn_nm, sgg_nm, emd_nm, detail_plcnm, adres, wtrplay_plc_type, wtrplay_sec, wtrplay_deep, wtrplay_deep_avg, year_visitor, acdt_co, x, y, manage_type, manage_at]],

            columns=["wtrplay_plc_nm", "ctprvn_nm", "sgg_nm", "emd_nm", "detail_plcnm", "adres", "wtrplay_plc_type", "wtrplay_sec", "wtrplay_deep", "wtrplay_deep_avg", "year_visitor", "acdt_co", "x", "y", "manage_type", "manage_at"]
        )

        # 데이터프레임에 추출한 데이터 추가
        df1 = pd.concat([df1, df])

print(df1)

print("반복 횟수:", counter)

df1.to_csv("일반지역_하천계곡.csv", index=False, encoding="cp949")

# %%
#위험지역
import requests
import pprint
import xml.etree.ElementTree as ET
import pandas as pd


url = "http://safemap.go.kr/openApiService/data/getWtrPlayData.do"
params = {
"serviceKey": "PHUYHKKL-PHUY-PHUY-PHUY-PHUYHKKLT1",
"numOfRows": "1334",
"pageNo": "1"
}

response = requests.get(url, params=params)

content = response.text

root = ET.fromstring(content)

# XML 데이터 구조 탐색
items = root.find("body").find("items")

counter = 0  # 반복 횟수를 저장할 변수

df1 = pd.DataFrame()  # 데이터를 저장할 데이터프레임 생성

for item in items.findall("item"):
    wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
    manage_at = item.find("MANAGE_AT").text

    if manage_at == "3" :
        counter += 1  # 반복 횟수 증가
        # 추출한 데이터 처리
        wtrplay_plc_nm = item.find("WTRPLAY_PLC_NM").text
        ctprvn_nm = item.find("CTPRVN_NM").text
        sgg_nm = item.find("SGG_NM").text
        emd_nm = item.find("EMD_NM").text
        detail_plcnm = item.find("DETAIL_PLCNM").text
        adres = item.find("ADRES").text
        wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
        wtrplay_sec = item.find("WTRPLAY_SEC").text
        wtrplay_deep = item.find("WTRPLAY_DEEP").text
        wtrplay_deep_avg = item.find("WTRPLAY_DEEP_AVG").text
        year_visitor = item.find("YEAR_VISITOR").text
        acdt_co = item.find("ACDT_CO").text
        x = item.find("X").text
        y = item.find("Y").text
        manage_type = item.find("MANAGEMENT_TYPE").text
        manage_at = item.find("MANAGE_AT").text

        #추출한 데이터 데이터프레임으로 변경
        df = pd.DataFrame( 
           [[wtrplay_plc_nm, ctprvn_nm, sgg_nm, emd_nm, detail_plcnm, adres, wtrplay_plc_type, wtrplay_sec, wtrplay_deep, wtrplay_deep_avg, year_visitor, acdt_co, x, y, manage_type, manage_at]],

            columns=["wtrplay_plc_nm", "ctprvn_nm", "sgg_nm", "emd_nm", "detail_plcnm", "adres", "wtrplay_plc_type", "wtrplay_sec", "wtrplay_deep", "wtrplay_deep_avg", "year_visitor", "acdt_co", "x", "y", "manage_type", "manage_at"]
        )

        # 데이터프레임에 추출한 데이터 추가
        df1 = pd.concat([df1, df])

print(df1)

print("반복 횟수:", counter)

df1.to_csv("위험지역_하천계곡.csv", index=False, encoding="cp949")
# Out:
#    wtrplay_plc_nm ctprvn_nm sgg_nm emd_nm     detail_plcnm
# 0             용호제       대전시    대덕구   신탄진동              용호제  \
# 0        적목리 용소폭포       경기도    가평군     북면      적목리 용소폭포 주변
# 0             황어대       강원도    강릉시    연곡면          폭포골야영장앞
# 0       연동산촌마을휴양지       강원도    강릉시    연곡면              가마소
# 0            용담계곡       강원도    화천군    사내면             용담계곡
# ..            ...       ...    ...    ...              ...
# 0             요강소      경상남도     함양    안의면              요강소
# 0      위천중학교 앞 솔숲      경상남도    거창군    위천면  위천중학교 앞 솔숲(위천천)
# 0             가마소      경상남도    거창군    북상면           창선교 인근
# 0             각시소      경상남도    거창군    가조면       고견사 주차장 아래
# 0       각사교 및 고래소      경상남도    합천군    가야면        소리길 입구 근처
#
#                        adres wtrplay_plc_type wtrplay_sec wtrplay_deep
# 0          대전광역시 대덕구 용호동 426               하천         100            5  \
# 0         경기도 가평군 북면 적목리 653               하천          30           10
# 0       강원도 강릉시 연곡면 퇴곡리 70-1               하천         700            2
# 0       강원도 강릉시 연곡면 삼산리 산140               하천         700            5
# 0         강원도 화천군 사내면 용담리 42               계곡       3,000            3
# ..                       ...              ...         ...          ...
# 0       경상남도 함양 안의면 상원리 1434               계곡         100            4
# 0       경상남도 거창군 위천면 장기리 390               계곡         250            3
# 0     경상남도 거창군 북상면 창선리 288-2               하천          60            4
# 0   경상남도 거창군 가조면 수월리 산28-1번지               계곡          20            3
# 0       경상남도 합천군 가야면 황산리 421               하천          30            3
#
#    wtrplay_deep_avg year_visitor acdt_co                  x
# 0                 2         null       0  14187808.67924486  \
# 0                 3         null       0  14185663.44133778
# 0                 1         null       1  14332013.73986227
# 0                 4         null       0  14319839.62884209
# 0                 1         null       0  14199438.93889278
# ..              ...          ...     ...                ...
# 0                 4         null       2  14224007.23956645
# 0                 2         null       1  14230346.99588661
# 0                 2         null       1  14224045.25517255
# 0                 1         null       1  14253191.01330764
# 0                 2         null       1  14263780.34666104
#
#                     y manage_type manage_at
# 0   4362592.804424809        위험지역         3
# 0    4577370.10949775        위험지역         3
# 0   4558118.076391784        위험지역         3
# 0   4562486.396017075        위험지역         3
# 0   4587401.567077986        위험지역         3
# ..                ...         ...       ...
# 0   4255811.534975966        위험지역         3
# 0   4267060.040300574        위험지역         3
# 0   4268349.477132638        위험지역         3
# 0   4263524.603517354        위험지역         3
# 0   4268309.623222301        위험지역         3
#
# [233 rows x 16 columns]
# 반복 횟수: 233

# %%
#일반지역 계곡
import requests
import pprint
import xml.etree.ElementTree as ET
import pandas as pd


url = "http://safemap.go.kr/openApiService/data/getWtrPlayData.do"
params = {
"serviceKey": "PHUYHKKL-PHUY-PHUY-PHUY-PHUYHKKLT1",
"numOfRows": "1334",
"pageNo": "1"
}

response = requests.get(url, params=params)

content = response.text

root = ET.fromstring(content)

# XML 데이터 구조 탐색
items = root.find("body").find("items")

counter = 0  # 반복 횟수를 저장할 변수

df1 = pd.DataFrame()  # 데이터를 저장할 데이터프레임 생성

for item in items.findall("item"):
    wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
    manage_at = item.find("MANAGE_AT").text

    if manage_at == "2" and wtrplay_plc_type == "계곡" :
        counter += 1  # 반복 횟수 증가
        # 추출한 데이터 처리
        wtrplay_plc_nm = item.find("WTRPLAY_PLC_NM").text
        ctprvn_nm = item.find("CTPRVN_NM").text
        sgg_nm = item.find("SGG_NM").text
        emd_nm = item.find("EMD_NM").text
        detail_plcnm = item.find("DETAIL_PLCNM").text
        adres = item.find("ADRES").text
        wtrplay_plc_type = item.find("WTRPLAY_PLC_TYPE").text
        wtrplay_sec = item.find("WTRPLAY_SEC").text
        wtrplay_deep = item.find("WTRPLAY_DEEP").text
        wtrplay_deep_avg = item.find("WTRPLAY_DEEP_AVG").text
        year_visitor = item.find("YEAR_VISITOR").text
        acdt_co = item.find("ACDT_CO").text
        x = item.find("X").text
        y = item.find("Y").text
        manage_type = item.find("MANAGEMENT_TYPE").text
        manage_at = item.find("MANAGE_AT").text

        #추출한 데이터 데이터프레임으로 변경
        df = pd.DataFrame( 
           [[wtrplay_plc_nm, ctprvn_nm, sgg_nm, emd_nm, detail_plcnm, adres, wtrplay_plc_type, wtrplay_sec, wtrplay_deep, wtrplay_deep_avg, year_visitor, acdt_co, x, y, manage_type, manage_at]],

            columns=["wtrplay_plc_nm", "ctprvn_nm", "sgg_nm", "emd_nm", "detail_plcnm", "adres", "wtrplay_plc_type", "wtrplay_sec", "wtrplay_deep", "wtrplay_deep_avg", "year_visitor", "acdt_co", "x", "y", "manage_type", "manage_at"]
        )

        # 데이터프레임에 추출한 데이터 추가
        df1 = pd.concat([df1, df])

print(df1)

print("반복 횟수:", counter)

df1.to_csv("일반지역_계곡.csv", index=False, encoding="cp949")
# Out:
#    wtrplay_plc_nm ctprvn_nm sgg_nm emd_nm detail_plcnm
# 0    관악산계곡어린이물놀이장       서울시    관악구    신림로       신림계곡지구  \
# 0          장안사 계곡     부산광역시    기장군    장안읍          장안사
# 0           대운산계곡     울산광역시    울주군    온양읍          애기소
# 0             가평천       경기도    가평군     북면   밤나무계곡오토캠핑장
# 0             가평천       경기도    가평군     북면        용소유원지
# ..            ...       ...    ...    ...          ...
# 0          용오름캠핑장       강원도    홍천군    서석면       용오름교아래
# 0              칙소       강원도    홍천군     동면           칙소
# 0             큰귕소       강원도    홍천군     동면          큰귕소
# 0         귕소(용담위)       강원도    홍천군     동면      귕소(용담위)
# 0            용담계곡       강원도    홍천군     동면     수타사 용담계곡
#
#                        adres wtrplay_plc_type wtrplay_sec wtrplay_deep
# 0        서울시 관악구 신림동 808-125               계곡         150            1  \
# 0   부산광역시 기장군 장안읍 장안리 664-21               계곡         150          1.5
# 0     울산광역시 울주군 온양읍 운화리 1403               계곡         500            4
# 0         경기도 가평군 북면 도대리 408               계곡         200            2
# 0       경기도 가평군 북면 도대리 269-5               계곡          40            2
# ..                       ...              ...         ...          ...
# 0        강원도 홍천군 서석면 검산길 263               계곡         100            2
# 0      강원도 홍천군 동면 신봉리 256-11               계곡         100            2
# 0          강원도 홍천군 동면 덕치리466               계곡         100            3
# 0          강원도 홍천군 동면 덕치리466               계곡         100            3
# 0          강원도 홍천군 동면 덕치리466               계곡         100            3
#
#    wtrplay_deep_avg year_visitor acdt_co            x            y
# 0               0.6           11       0  14131845.97  4503708.725  \
# 0                 1          100       0  14385251.64  4214446.418
# 0                 1            3       1  14387223.57  4217359.284
# 0                 1        0.921       1  14189983.68  4574052.102
# 0                 2         1.39       0  14191841.37  4570724.909
# ..              ...          ...     ...          ...          ...
# 0                 1            2       0  14275162.65  4540073.701
# 0                 1            3       0  14245586.71  4535842.774
# 0               1.5            1       0  14241755.35  4536529.166
# 0               1.5            1       0  14241755.35  4536529.166
# 0                 2           20       1  14241755.35  4536529.166
#
#    manage_type manage_at
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# ..         ...       ...
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
# 0         일반지역         2
#
# [121 rows x 16 columns]
# 반복 횟수: 121
