# %%
#csv파일 가져오기

import pandas as pd
import numpy as np

df = pd.read_csv('./top10_valley.csv', encoding='utf-8')
df
# Out:
#            농월정     고도(농월정)       농월정_1     깊이(농월정)       농월정_2   경사도(농월정)
# 0     0.000000  242.601669    0.000000  196.537201    0.000000  12.536400  \
# 1   131.541881  254.958313   43.847294  119.157303   43.847294  21.611601
# 2   202.190037  235.645920   87.694587   61.190399   87.694587  16.601500
# 3   281.420990  235.400269  131.541881  128.329300  131.541881  19.511200
# 4   332.396391  235.400269  166.865959  151.217804  166.865959  15.179700
# ..         ...         ...         ...         ...         ...        ...
# 62         NaN         NaN         NaN         NaN         NaN        NaN
# 63         NaN         NaN         NaN         NaN         NaN        NaN
# 64         NaN         NaN         NaN         NaN         NaN        NaN
# 65         NaN         NaN         NaN         NaN         NaN        NaN
# 66         NaN         NaN         NaN         NaN         NaN        NaN
#
#            옥계리     고도(옥계리)        옥계리_1     깊이(옥계리)  ...       요강소_1
# ...

# %%
#"농월정"열을 x값으로 가져오고 "고도(농월정)"열을 y값으로 가져온다.

x = df['농월정']
y = df['고도(농월정)']

x1 = df['옥계리']
y1 = df['고도(옥계리)']

x2 = df['용추']
y2 = df['고도(용추)']

x3 = df['신선계곡']
y3 = df['고도(신선계곡)']

x4 = df['하옥계곡']
y4 = df['고도(하옥계곡)']

x5 = df['요강소']
y5 = df['고도(요강소)']

x6 = df['용소폭포']
y6 = df['고도(용소폭포)']
#x,y값을 이용하여 그래프를 그린다.

import matplotlib.pyplot as plt

plt.plot(x,y, color='red')#농월정
plt.plot(x1,y1, color='orange')#옥계리
plt.plot(x2,y2, color='yellow')#용추
plt.plot(x3,y3, color='green')#신선계곡
plt.plot(x4,y4, color='blue')#하옥계곡
plt.plot(x5,y5, color='skyblue')#요강소
plt.plot(x6,y6, color='purple') #용소폭포

#범례 추가
plt.legend(['농월정','옥계리','용추','신선계곡','하옥계곡','요강소','용소폭포'])

#x축 이름
plt.xlabel('물놀이 구간')

#y축 이름
plt.ylabel('고도(m)')

plt.show()

# %% [markdown]
# - 전반적으로 150~ 250 사이에 위치하는 계곡들이다
# - 요강소 같은 경우는 고도가 350m이상 매우 높은 상류에 위치해 있다

# %%
#시리즈를 리스트형태로 변환
plt.boxplot([list(y.dropna()), list(y1.dropna()), list(y2.dropna()), list(y3.dropna()), list(y4.dropna()), list(y5.dropna()), list(y6.dropna())])
plt.ylabel('고도(m)')

#x값 변경
plt.xticks([1,2,3,4,5,6,7], ['농월정','옥계리','용추','신선계곡','하옥계곡','요강소','용소폭포'])

plt.show()

# %%
#농월정
a = df['농월정']
a_1 = df['고도(농월정)']
b = df['농월정_1']
b_1 = df['깊이(농월정)']
c = df['농월정_2']
c_1 = df['경사도(농월정)']


#옥계리
a1 = df['옥계리']
a1_1 = df['고도(옥계리)']
b1 = df['옥계리_1']
b1_1 = df['깊이(옥계리)']
c1 = df['옥계리_2']
c1_1 = df['경사도(옥계리)']

#용추
a2 = df['용추']
a2_1 = df['고도(용추)']
b2 = df['용추_1']
b2_1 = df['깊이(용추)']
c2 = df['용추_2']
c2_1 = df['경사도(용추)']

#신선계곡
a3 = df['신선계곡']
a3_1 = df['고도(신선계곡)']
b3 = df['신선계곡_1']
b3_1 = df['깊이(신선계곡)']
c3 = df['신선계곡_2']
c3_1 = df['경사도(신선계곡)']


#하옥계곡
a4 = df['하옥계곡']
a4_1 = df['고도(하옥계곡)']
b4 = df['하옥계곡_1']
b4_1 = df['깊이(하옥계곡)']
c4 = df['하옥계곡_2']
c4_1 = df['경사도(하옥계곡)']

#요강소
a5 = df['요강소']
a5_1 = df['고도(요강소)']
b5 = df['요강소_1']
b5_1 = df['깊이(요강소)']
c5 = df['요강소_2']
c5_1 = df['경사도(요강소)']

#용소폭포
a6 = df['용소폭포']
a6_1 = df['고도(용소폭포)']
b6 = df['용소폭포_1']
b6_1 = df['깊이(용소폭포)']
c6 = df['용소폭포_2']
c6_1 = df['경사도(용소폭포)']


#농월정의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
fig, axs = plt.subplots(3,3, figsize=(15,10))


axs[0,0].plot(a,a_1, color='red')#고도
axs[0,0].plot(b,b_1, color='orange')#깊이
axs[0,0].set_ylim(0, 400)

ax1 = axs[0,0].twinx()#오른쪽 y축 생성

ax1.plot(c,c_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax1.set_ylim(0, c_1.max())
ax1.set_ylabel('경사도', color='green')
ax1.tick_params(axis='y', labelcolor='green')
axs[0,0].set_title('농월정')

#옥계리의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
axs[0,1].plot(a1,a1_1, color='red')#고도
axs[0,1].plot(b1,b1_1, color='orange')#깊이
axs[0,1].set_ylim(0, 400)

ax2 = axs[0,1].twinx()#오른쪽 y축 생성

ax2.plot(c1,c1_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax2.set_ylim(0, c1_1.max())
ax2.set_ylabel('경사도', color='green')
ax2.tick_params(axis='y', labelcolor='green')
axs[0,1].set_title('옥계리')

#용추의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
axs[0,2].plot(a2,a2_1, color='red')#고도
axs[0,2].plot(b2,b2_1, color='orange')#깊이
axs[0,2].set_ylim(0, 400)

ax3 = axs[0,2].twinx()#오른쪽 y축 생성

ax3.plot(c2,c2_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax3.set_ylim(0, c2_1.max())
ax3.set_ylabel('경사도', color='green')
ax3.tick_params(axis='y', labelcolor='green')
axs[0,2].set_title('용추')

#신선계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
axs[1,0].plot(a3,a3_1, color='red')#고도
axs[1,0].plot(b3,b3_1, color='orange')#깊이
axs[1,0].set_ylim(0, 400)

ax4 = axs[1,0].twinx()#오른쪽 y축 생성

ax4.plot(c3,c3_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax4.set_ylim(0, c3_1.max())
ax4.set_ylabel('경사도', color='green')
ax4.tick_params(axis='y', labelcolor='green')
axs[1,0].set_title('신선계곡')

#하옥계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
axs[1,1].plot(a4,a4_1, color='red')#고도
axs[1,1].plot(b4,b4_1, color='orange')#깊이
axs[1,1].set_ylim(0, 400)

ax5 = axs[1,1].twinx()#오른쪽 y축 생성

ax5.plot(c4,c4_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax5.set_ylim(0, c4_1.max())
ax5.set_ylabel('경사도', color='green')
ax5.tick_params(axis='y', labelcolor='green')
axs[1,1].set_title('하옥계곡')

#요강소의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
axs[1,2].plot(a5,a5_1, color='red')#고도
axs[1,2].plot(b5,b5_1, color='orange')#깊이
axs[1,2].set_ylim(0, 400)

ax6 = axs[1,2].twinx()#오른쪽 y축 생성

ax6.plot(c5,c5_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax6.set_ylim(0, c5_1.max())
ax6.set_ylabel('경사도', color='green')
ax6.tick_params(axis='y', labelcolor='green')
axs[1,2].set_title('요강소')

#용소폭포의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
axs[2,0].plot(a6,a6_1, color='red')#고도
axs[2,0].plot(b6,b6_1, color='orange')#깊이
axs[2,0].set_ylim(0, 400)

ax7 = axs[2,0].twinx()#오른쪽 y축 생성

ax7.plot(c6,c6_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax7.set_ylim(0, c6_1.max())
ax7.set_ylabel('경사도', color='green')
ax7.tick_params(axis='y', labelcolor='green')
axs[2,0].set_title('용소폭포')
# Out:
# Text(0.5, 1.0, '용소폭포')

# %%
#농월정
a = df['농월정']
a_1 = df['고도(농월정)']
b = df['농월정_1']
b_1 = df['깊이(농월정)']
c = df['농월정_2']
c_1 = df['경사도(농월정)']


#옥계리
a1 = df['옥계리']
a1_1 = df['고도(옥계리)']
b1 = df['옥계리_1']
b1_1 = df['깊이(옥계리)']
c1 = df['옥계리_2']
c1_1 = df['경사도(옥계리)']

#용추
a2 = df['용추']
a2_1 = df['고도(용추)']
b2 = df['용추_1']
b2_1 = df['깊이(용추)']
c2 = df['용추_2']
c2_1 = df['경사도(용추)']

#신선계곡
a3 = df['신선계곡']
a3_1 = df['고도(신선계곡)']
b3 = df['신선계곡_1']
b3_1 = df['깊이(신선계곡)']
c3 = df['신선계곡_2']
c3_1 = df['경사도(신선계곡)']


#하옥계곡
a4 = df['하옥계곡']
a4_1 = df['고도(하옥계곡)']
b4 = df['하옥계곡_1']
b4_1 = df['깊이(하옥계곡)']
c4 = df['하옥계곡_2']
c4_1 = df['경사도(하옥계곡)']

#요강소
a5 = df['요강소']
a5_1 = df['고도(요강소)']
b5 = df['요강소_1']
b5_1 = df['깊이(요강소)']
c5 = df['요강소_2']
c5_1 = df['경사도(요강소)']

#용소폭포
a6 = df['용소폭포']
a6_1 = df['고도(용소폭포)']
b6 = df['용소폭포_1']
b6_1 = df['깊이(용소폭포)']
c6 = df['용소폭포_2']
c6_1 = df['경사도(용소폭포)']


#농월정의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
fig, axs = plt.subplots(3,3, figsize=(15,10))


axs[0,0].plot(b,b_1, color='orange')#깊이
axs[0,0].set_ylim(0, 600)

ax1 = axs[0,0].twinx()#오른쪽 y축 생성

ax1.plot(c,c_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax1.set_ylim(0, c_1.max())
ax1.set_ylabel('경사도', color='green')
ax1.tick_params(axis='y', labelcolor='green')
axs[0,0].set_title('농월정')

#옥계리의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[0,1].plot(b1,b1_1, color='orange')#깊이
axs[0,1].set_ylim(0, 600)

ax2 = axs[0,1].twinx()#오른쪽 y축 생성

ax2.plot(c1,c1_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax2.set_ylim(0, c1_1.max())
ax2.set_ylabel('경사도', color='green')
ax2.tick_params(axis='y', labelcolor='green')
axs[0,1].set_title('옥계리')

#용추의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[0,2].plot(b2,b2_1, color='orange')#깊이
axs[0,2].set_ylim(0, 600)

ax3 = axs[0,2].twinx()#오른쪽 y축 생성

ax3.plot(c2,c2_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax3.set_ylim(0, c2_1.max())
ax3.set_ylabel('경사도', color='green')
ax3.tick_params(axis='y', labelcolor='green')
axs[0,2].set_title('용추')

#신선계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[1,0].plot(b3,b3_1, color='orange')#깊이
axs[1,0].set_ylim(0, 600)

ax4 = axs[1,0].twinx()#오른쪽 y축 생성

ax4.plot(c3,c3_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax4.set_ylim(0, c3_1.max())
ax4.set_ylabel('경사도', color='green')
ax4.tick_params(axis='y', labelcolor='green')
axs[1,0].set_title('신선계곡')

#하옥계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[1,1].plot(b4,b4_1, color='orange')#깊이
axs[1,1].set_ylim(0, 600)

ax5 = axs[1,1].twinx()#오른쪽 y축 생성

ax5.plot(c4,c4_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax5.set_ylim(0, c4_1.max())
ax5.set_ylabel('경사도', color='green')
ax5.tick_params(axis='y', labelcolor='green')
axs[1,1].set_title('하옥계곡')

#요강소의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[1,2].plot(b5,b5_1, color='orange')#깊이
axs[1,2].set_ylim(0, 600)

ax6 = axs[1,2].twinx()#오른쪽 y축 생성

ax6.plot(c5,c5_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax6.set_ylim(0, c5_1.max())
ax6.set_ylabel('경사도', color='green')
ax6.tick_params(axis='y', labelcolor='green')
axs[1,2].set_title('요강소')

#용소폭포의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[2,0].plot(b6,b6_1, color='orange')#깊이
axs[2,0].set_ylim(0, 600)

ax7 = axs[2,0].twinx()#오른쪽 y축 생성

ax7.plot(c6,c6_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax7.set_ylim(0, c6_1.max())
ax7.set_ylabel('경사도', color='green')
ax7.tick_params(axis='y', labelcolor='green')
axs[2,0].set_title('용소폭포')
# Out:
# Text(0.5, 1.0, '용소폭포')

# %% [markdown]
# low10 그래프

# %%
#csv파일 가져오기

import pandas as pd
import numpy as np

df_low = pd.read_csv('./low10_valley.csv', encoding='utf-8')
df_low
# Out:
#       대장동계곡_1   고도(대장동계곡)    대장동계곡_2   깊이(대장동계곡)    대장동계곡_3  경사도(대장동계곡)
# 0    0.000000  193.866684   0.000000  334.761200   0.000000     14.9592  \
# 1   19.903884  193.866684  19.903884  342.641510  19.903884     12.2601
# 2   37.330302  176.745193  37.330302  305.359497  37.330302     12.2601
# 3   60.701813  176.745193  60.701813  343.442413  60.701813     10.4308
# 4   76.187817  176.745193  76.187817  343.442413  76.187817     10.4308
# ..        ...         ...        ...         ...        ...         ...
# 59        NaN         NaN        NaN         NaN        NaN         NaN
# 60        NaN         NaN        NaN         NaN        NaN         NaN
# 61        NaN         NaN        NaN         NaN        NaN         NaN
# 62        NaN         NaN        NaN         NaN        NaN         NaN
# 63        NaN         NaN        NaN         NaN        NaN         NaN
#
#         송하계곡_1    고도(송하계곡)      송하계곡_2    깊이(송하계곡)  ...   성주봉휴양림_2
# ...

# %%
#"농월정"열을 x값으로 가져오고 "고도(농월정)"열을 y값으로 가져온다.
from matplotlib import font_manager


x = df_low['대장동계곡_1']
y = df_low['고도(대장동계곡)']

x1 = df_low['송하계곡_1']
y1 = df_low['고도(송하계곡)']

x2 = df_low['본신계곡_1']
y2 = df_low['고도(본신계곡)']

x3 = df_low['얼음골_1']
y3 = df_low['고도(얼음골)']

x4 = df_low['동산계곡_1']
y4 = df_low['고도(동산계곡)']

x5 = df_low['용루골천_1']
y5 = df_low['고도(용루골천)']

x6 = df_low['삼의계곡_1']
y6 = df_low['고도(삼의계곡)']

x7 = df_low['성주봉휴양림_1']
y7 = df_low['고도(성주봉휴양림)']

x8 = df_low['치산계곡_1']
y8 = df_low['고도(치산계곡)']

x9 = df_low['용담계곡_1']
y9 = df_low['고도(용담계곡)']
#x,y값을 이용하여 그래프를 그린다.

import matplotlib.pyplot as plt

plt.plot(x,y, color='red')
plt.plot(x1,y1, color='orange')
plt.plot(x2,y2, color='yellow')
plt.plot(x3,y3, color='green')
plt.plot(x4,y4, color='blue')
plt.plot(x5,y5, color='skyblue')
plt.plot(x6,y6, color='purple') 



#범례 추가
plt.legend(['대장동계곡','송하계곡','본신계곡','얼음골','동산계곡','용루골천','삼의계곡','성주봉휴양림','치산계곡','용담계곡'])

#x축 이름
plt.xlabel('물놀이 구간')

#y축 이름
plt.ylabel('고도(m)')

plt.show()

# %%
#대장동계곡
A = df_low['대장동계곡_1']
A_1 = df_low['고도(대장동계곡)']
B = df_low['대장동계곡_2']
B_1 = df_low['깊이(대장동계곡)']
C = df_low['대장동계곡_3']
C_1 = df_low['경사도(대장동계곡)']


#송하계곡
A1 = df_low['송하계곡_1']
A1_1 = df_low['고도(송하계곡)']
B1 = df_low['송하계곡_2']
B1_1 = df_low['깊이(송하계곡)']
C1 = df_low['송하계곡_3']
C1_1 = df_low['경사도(송하계곡)']

#본신계곡
A2 = df_low['본신계곡_1']
A2_1 = df_low['고도(본신계곡)']
B2 = df_low['본신계곡_2']
B2_1 = df_low['깊이(본신계곡)']
C2 = df_low['본신계곡_3']
C2_1 = df_low['경사도(본신계곡)']

#얼음골
A3 = df_low['얼음골_1']
A3_1 = df_low['고도(얼음골)']
B3 = df_low['얼음골_2']
B3_1 = df_low['깊이(얼음골)']
C3 = df_low['얼음골_3']
C3_1 = df_low['경사도(얼음골)']

#동산계곡
A4 = df_low['동산계곡_1']
A4_1 = df_low['고도(동산계곡)']
B4 = df_low['동산계곡_2']
B4_1 = df_low['깊이(동산계곡)']
C4 = df_low['동산계곡_3']
C4_1 = df_low['경사도(동산계곡)']

#용루골천
A5 = df_low['용루골천_1']
A5_1 = df_low['고도(용루골천)']
B5 = df_low['용루골천_2']
B5_1 = df_low['깊이(용루골천)']
C5 = df_low['용루골천_3']
C5_1 = df_low['경사도(용루골천)']

#삼의계곡
A6 = df_low['삼의계곡_1']
A6_1 = df_low['고도(삼의계곡)']
B6 = df_low['삼의계곡_2']
B6_1 = df_low['깊이(삼의계곡)']
C6 = df_low['삼의계곡_3']
C6_1 = df_low['경사도(삼의계곡)']

#성주봉휴양림
A7 = df_low['성주봉휴양림_1']
A7_1 = df_low['고도(성주봉휴양림)']
B7 = df_low['성주봉휴양림_2']
B7_1 = df_low['깊이(성주봉휴양림)']
C7 = df_low['성주봉휴양림_3']
C7_1 = df_low['경사도(성주봉휴양림)']

#치산계곡
A8 = df_low['치산계곡_1']
A8_1 = df_low['고도(치산계곡)']
B8 = df_low['치산계곡_2']
B8_1 = df_low['깊이(치산계곡)']
C8 = df_low['치산계곡_3']
C8_1 = df_low['경사도(치산계곡)']

#용담계곡
A9 = df_low['용담계곡_1']
A9_1 = df_low['고도(용담계곡)']
B9 = df_low['용담계곡_2']
B9_1 = df_low['깊이(용담계곡)']
C9 = df_low['용담계곡_3']
C9_1 = df_low['경사도(용담계곡)']


#대장동계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.
fig, axs = plt.subplots(4,3, figsize=(15,10))


axs[0,0].plot(B,B_1, color='orange')#깊이
axs[0,0].set_ylim(0, 600)

ax1 = axs[0,0].twinx()#오른쪽 y축 생성

ax1.plot(C,C_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax1.set_ylim(0, C_1.max())
ax1.set_ylabel('경사도', color='green')
ax1.tick_params(axis='y', labelcolor='green')
axs[0,0].set_title('대장동계곡')

#송하계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[0,1].plot(B1,B1_1, color='orange')#깊이
axs[0,1].set_ylim(0, 600)

ax2 = axs[0,1].twinx()#오른쪽 y축 생성

ax2.plot(C1,C1_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax2.set_ylim(0, C1_1.max())
ax2.set_ylabel('경사도', color='green')
ax2.tick_params(axis='y', labelcolor='green')
axs[0,1].set_title('송하계곡')

#본신의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[0,2].plot(B2,B2_1, color='orange')#깊이
axs[0,2].set_ylim(0, 600)

ax3 = axs[0,2].twinx()#오른쪽 y축 생성

ax3.plot(C2,C2_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax3.set_ylim(0, C2_1.max())
ax3.set_ylabel('경사도', color='green')
ax3.tick_params(axis='y', labelcolor='green')
axs[0,2].set_title('본신계곡')

#얼음골의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[1,0].plot(B3,B3_1, color='orange')#깊이
axs[1,0].set_ylim(0, 600)

ax4 = axs[1,0].twinx()#오른쪽 y축 생성

ax4.plot(C3,C3_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax4.set_ylim(0, C3_1.max())
ax4.set_ylabel('경사도', color='green')
ax4.tick_params(axis='y', labelcolor='green')
axs[1,0].set_title('얼음골')

#동산계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[1,1].plot(B4,B4_1, color='orange')#깊이
axs[1,1].set_ylim(0, 600)

ax5 = axs[1,1].twinx()#오른쪽 y축 생성

ax5.plot(C4,C4_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax5.set_ylim(0, C4_1.max())
ax5.set_ylabel('경사도', color='green')
ax5.tick_params(axis='y', labelcolor='green')
axs[1,1].set_title('동산계곡')

#용루골천의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[1,2].plot(B5,B5_1, color='orange')#깊이
axs[1,2].set_ylim(0, 600)

ax6 = axs[1,2].twinx()#오른쪽 y축 생성

ax6.plot(C5,C5_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax6.set_ylim(0, C5_1.max())
ax6.set_ylabel('경사도', color='green')
ax6.tick_params(axis='y', labelcolor='green')
axs[1,2].set_title('용루골천')

#삼의계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[2,0].plot(B6,B6_1, color='orange')#깊이
axs[2,0].set_ylim(0, 600)

ax7 = axs[2,0].twinx()#오른쪽 y축 생성

ax7.plot(C6,C6_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax7.set_ylim(0, C6_1.max())
ax7.set_ylabel('경사도', color='green')
ax7.tick_params(axis='y', labelcolor='green')
axs[2,0].set_title('삼의계곡')

#성주봉휴양림의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[2,1].plot(B7,B7_1, color='orange')#깊이
axs[2,1].set_ylim(0, 600)

ax8 = axs[2,1].twinx()#오른쪽 y축 생성

ax8.plot(C7,C7_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax8.set_ylim(0, C7_1.max())
ax8.set_ylabel('경사도', color='green')
ax8.tick_params(axis='y', labelcolor='green')
axs[2,1].set_title('성주봉휴양림')

#치산계곡의 고도, 깊이, 경사도 데이터를 이용하여 그래프를 그린다.

axs[2,2].plot(B8,B8_1, color='orange')#깊이
axs[2,2].set_ylim(0, 600)

ax9 = axs[2,2].twinx()#오른쪽 y축 생성

ax9.plot(C8,C8_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax9.set_ylim(0, C8_1.max())
ax9.set_ylabel('경사도', color='green')
ax9.tick_params(axis='y', labelcolor='green')
axs[2,2].set_title('치산계곡')

#용담계곡

axs[3,0].plot(B9,B9_1, color='orange')#깊이
axs[3,0].set_ylim(0, 600)

ax10 = axs[3,0].twinx()#오른쪽 y축 생성

ax10.plot(C9,C9_1, color='green',linestyle='dotted', alpha=0.5)#경사도
ax10.set_ylim(0, C9_1.max())
ax10.set_ylabel('경사도', color='green')
ax10.tick_params(axis='y', labelcolor='green')
axs[3,0].set_title('용담계곡')
# Out:
# Text(0.5, 1.0, '용담계곡')
